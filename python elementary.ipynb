# %% [markdown]
# # This is introduction to jupiter notebook
# ## This is a bit smaller
# ###### this is the least header
#
#
# This is jupiter notebook,for writing python code, it is easy as said to use
# # how to create list
# 1. step one
# 2. step two
# 3. step three
#
# - point 1
# - point two
# - point III![canon%20camera%201.jpg](attachment:canon%20camera%201.jpg)

# %%
print ("hello,am learning how to write a python code")
# Out:
# hello,am learning how to write a python code

# %%
# variable and identifier 
# variable is an entity located in a computer memory
# identifier are used to identify variables or name of variable
num1 = 2
# note (num1) is the identifier for variable 2 in the computer memeory

# %%
print(num1)
# Out:
# 2

# %% [markdown]
# # rules for naming variables
# 1. variable names cant start with a number,although number can be find anywhere else
# 2. any special character cant be included in variable name except underscore(_)
# 3. space cant be use to join two words together use underscore(_) instead
# 4. variable name should be descriptive

# %%
first_name = "wasiu"
last_name = 'idowu'
age = 19
origin ="ogun"
print ("my name is",first_name,last_name,"i am",age,"years old",'from',origin,'state')
# Out:
# my name is wasiu idowu i am 19 years old from ogun state

# %%
# input is used to take input from the user....anything that comes being entered as a text data type
first_name = input ('enter your firstname')
last_name = input ('enter your lastname')
age = input ("enter your age")
origin = input ("enter your state of origin")
print ("hello everyone,my name is",first_name,last_name,"i am",age,"years old",'from',origin,'state')
# Out:
# enter your firstnamekunle
# enter your lastnameadeoti
# enter your age30
# enter your state of originlagos
# hello everyone,my name is kunle adeoti i am 30 years old from lagos state

# %% [markdown]
# # data type conversions keywords
# ### to check the datatype in python the keyword is (type)
#
# -1.int
# -2.float
# -3. str
# -4. complex

# %%
num_1 = int(input('please enter the first number'))
num_2 = int(input('please enter the second number'))
total = num_1 + num_2
print ('the sum of the two numbers entered is',total)
# Out:
# please enter the first number45
# please enter the second number32
# the sum of the two numbers entered is 77

# %% [markdown]
# # operators in python
# 1. Arithmetic
# 2. Comparison
# 3. Assignment
# 4. logical
# 5. Membership
# 6. identity
# 7. bitwise

# %%
# ARITHMETIC
# PLUS
a = 6
b = 7
total = a + b
print (total)
# Out:
# 13

# %%
# ARITHMETIC
# minus
a = 6
b = 7
total = a - b
print (total)
# Out:
# -1

# %%
# ARITHMETIC
# MULTIPLICATION
a = 6
b = 2
total = a * b
print (total)
# Out:
# 12

# %%
# ARITHMETIC
# POWER (**)
a = 6
b = 2
total = a ** b
print (total)
# Out:
# 36

# %%
# ARITHMETIC
# DIVISION (/)
a = 12
b = 2
total = a / b
print (total)
# Out:
# 6.0

# %%
# ARITHMETIC
# MODULUS (%) TO RETURN THE REMAINDER OF A DIVISION
a = 10
b = 3
total = a % b
print (total)
# Out:
# 1

# %% [markdown]
# ## 2. COMPARISON IS USED TO COMPARE TWO OR MORE VARIABLES AND RETURN BOOLIAN RESULT (TRUE/FALSE)

# %%
# COMPARISON
# GREATER THAN (>)
a = 12
b = 10
a > b
# Out:
# True

# %%
# COMPARISON
# GREATER THAN OR EQUAL TO(>=)
a = 12
b = 13
a >= b
# Out:
# False

# %%
# COMPARISON
# LESSER THAN (<)
a = 7
b = 10
a < b
# Out:
# True

# %%
# COMPARISON
# LESSER THAN OR EQUAL TO (<=)
a = 12
b = 10
a <= b
# Out:
# False

# %%
# COMPARISON
# EQUAL TO (==)
a = 12
b = 12
a == b
# Out:
# True

# %%
# COMPARISON
# NOT EQUALTO (!=)
a = 12
b = 10
a != b
# Out:
# True

# %% [markdown]
# ## ASSIGNMENT -
# 1. # EQUAL SIGN
#  EXAMPLE : a = 5 i.e assigning a to 5

# %%
2.# increment
a = 5
a += 5
print (a)
# Out:
# 10

# %%
2.# decrement
a = 7
a -= 5
print (a)
# Out:
# 2

# %%
2.# multiple increment
a = 5
a *= 5
print (a)
# Out:
# 25

# %% [markdown]
# # logical (AND/OR)

# %%
a = 5
b = 10
c = 15
(a>b)and (b<c)
# Out:
# False

# %%
a = 5
b = 10
c = 15
(a>b) or (b<c)
# Out:
# True

# %% [markdown]
# # MEMBERSHIP; (IN / NOT IN)....IT REURNS BOOLEAN RESULT

# %%
# IN
name_list = ('olaitan','kemi','shola','biola')
"ade" in name_list
# Out:
# False

# %%
# not in
name_list = ('olaitan','kemi','shola','biola')
"ade" not in name_list
# Out:
# True

# %% [markdown]
# # IDENTITY (IS, IS NOT)

# %%
# IS
a = 3
b = 4
c = 3
print (a is b)
print (a is c)
# Out:
# False
# True

# %%
# IS NOT
a = 3
b = 4
c = 3
print (a is not b)
print (a is not c)
# Out:
# True
# False

# %%
born_year = int(input("please insert your birth year"))
Age = 2024 -born_year
print ("i am",Age,'years old')
# Out:
# please insert your birth year2000
# i am 24 years old

# %%
born_year = int(input("please insert your birth year"))
Age = 2024-born_year
print ('your age is',Age)
# Out:
# please insert your birth year2000
# your age is 24
